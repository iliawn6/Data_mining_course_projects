# %% [markdown]
# <h1 align=center style="line-height:300%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# سری چهارم تمارین عملی درس داده کاوی
# </font>
# </h1>
# <h3 align=center style="line-height:100%;font-family:vazir;color:#0099cc">
# استاد درس: دکتر مریم امیر مزلقانی
# </h3>
# <h5 align=center style="font-size: 20px;line-height:100%;font-family:vazir;color:#0099cc">
# طراح تمرین عملی: محمد چوپان
#     </h5>
# <p align=center style="font-size: 16;line-height:100%;font-family:vazir;color:#0099cc">
#     <a href="mailto:Aut.DataMining.Fall@gmail.com">Aut.DataMining.Fall@gmail.com</a>
# </p>

# %% [markdown]
# <div dir="rtl">
#
# <p dir=rtl style="font-size: 16;line-height:100%;font-family:vazir;color:red;direction:rtl">
# لطفا خواسته های تمرین را در بخش خودش انجام دهید.
# </p>
# </div>

# %% [markdown]
# # HW4

# %% [markdown]
# ## Imports

# %%
## TODO
import pandas as pd
import numpy
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import r2_score
import seaborn as sns

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# <div dir="rtl">
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     در این قسمت دیتاست کشور ها را با استفاده از کتابخانه pandas بخوانید.
# </font>
# </p>
# </div>

# %%
## TODO
# Create a dataframe from csv file
df = pd.read_csv('Country-data.csv')

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# <div dir="rtl">
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در این قسمت شما باید با استفاده از رسم نمودار های مختلف همانند نمودار جعبه ای و یا نقشه گرمایی داده ها را تحلیل کنید.
# حداقل 5 نمودار مختلف را رسم کنید.
# </font>
# </p>
# </div>

# %% [markdown]
# ## Pair Plot

# %%
# Pairplot
sns.pairplot(df)
plt.title("Pairplot of Features")
plt.show()

# %% [markdown]
# <div dir="rtl">
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     در نمودار بالا ارتباط هر دو فیچر با یکدیگر را مشاهده میکنیم. بعضی جفت ها ارتباط خطی یا نمایی واضح دارند اما برخی از آنها ارتباط واضحی را نشان نمیدهند.
#
# </font>
# </p>
# </div>

# %% [markdown]
# ## Box Plots

# %%
# Boxplots
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, orient="h")
plt.xscale('log')  # Set x-axis to logarithmic scale
plt.title("Boxplot of Features")
plt.show()

# %% [markdown]
# <div dir="rtl">
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     باکس پلات ها برای مشاهده و بررسی نحوه توزیع فیچر ها استفاده میشوند. در فیچرهای بالا از مقیاس لوگاریتمی برای محور ایکس استفاده شده (چون بازه ی value های فیچر ها بسیار مختلف بودند).
# </font>
# </p>
# </div>

# %% [markdown]
# ## Correlation HeatMap

# %%
# Heatmap

# Drop the 'country' column before generating the correlation matrix
df_corr = df.drop(columns=['country'])

plt.figure(figsize=(10, 8))
sns.heatmap(df_corr.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# <div dir="rtl">
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# نمودار heatmap کریلیشن (همبستگی) یک روش قوی برای نمایش الگوهای همبستگی بین متغیرها در یک ماتریس دوبعدی است. این نمودار با استفاده از رنگ‌ها و گرادیان‌ها برای نشان دادن میزان همبستگی میان متغیرها استفاده می‌شود، به طوری که مقادیر مثبت و منفی همبستگی با رنگ‌های مختلف نشان داده می‌شوند. این نمودار برای تشخیص الگوهای همبستگی و ارتباطات بین متغیرها در داده‌های چندمتغیره بسیار کارآمد است.</font>
# </p>
# </div>

# %% [markdown]
# ## Bar Plot

# %%
# Bar Plot
top_15_countries = df.nlargest(15, 'gdpp')  # Select top 15 countries by GDP per capita

plt.figure(figsize=(12, 8))
sns.barplot(x='country', y='gdpp', data=top_15_countries)
plt.xticks(rotation=90)
plt.title("Bar Plot of GDP per Capita for Top 15 Countries")
plt.show()

# %% [markdown]
# <div dir="rtl">
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     این نمودار به وضوح نشان می‌دهد کدام کشورها دارای بیشترین میزان GDP per capita هستند  .
# </font>
# </p>
# </div>

# %% [markdown]
# ## JointPlot

# %%
sns.jointplot(x='inflation', y='life_expec', data=df, kind='reg')
plt.xlabel("Inflation")
plt.ylabel("Life Expectancy")
plt.title("Jointplot: Life Expectancy vs. Inflation")
plt.show()

# %% [markdown]
# <div dir="rtl">
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     این نمودار علاوه بر ارتباط بین دو فیچر، توزیع آنها را نیز نمایش میدهد.
# </font>
# </p>
# </div>

# %% [markdown]
# ### PCA

# %% [markdown]
# <div dir="rtl">
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# داده های خود را با استفاده از الگوریتم PCA به 2 بعد کاهش دهید.دقت کنید که به داده های اصلی نیاز داریم. پس حتما آن ها را ذخیره کنید.
# </font>
# </p>
# </div>

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np

# Selecting numerical columns for PCA
pca_cols = ['child_mort', 'exports', 'health', 'imports', 'income', 'inflation', 'life_expec', 'total_fer', 'gdpp']
X = df[pca_cols]

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Create a DataFrame for the reduced data
pca_df = pd.DataFrame(data=X_pca, columns=['PC1', 'PC2']).astype(np.float32)

# Scatter plot do demonstrate new features
plt.scatter(pca_df['PC1'],pca_df['PC2'])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA: 2-Dimensional Representation with Country Labels')
plt.show()

# %% [markdown]
# ## Clustering

# %% [markdown]
# ### Similarity

# %% [markdown]
# <div dir="rtl">
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3> در این مرحله نیاز است که ماتریس شباهت دادگان را به دست آورید.برای هر یک از داده ها برداری از ویژگی هایش را در نظر گرفته  و ماتریس شباهت رابرای کل  دیتاست به دست آورید.برای معیار شباهت نیز یک بار از فاصله اقلیدسی و یک بار از شباهت کوسینوسی کمک بگیرید.
# این کار را هم برای داده های کاهش داده شده و هم برای داده های اصلی انجام دهید.
# </font>
# </p>
# </div>

# %% [markdown]
# ### For reduced Dataset with PCA

# %%
## TODO
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import euclidean_distances, cosine_similarity

X_pca = pca_df[['PC1', 'PC2']]

# Euclidean distances
euclidean_dist_matrix = euclidean_distances(X_pca)

# Cosine similarities
cosine_sim_matrix = cosine_similarity(X_pca)

# Convert distance matrices to similarity matrices
euclidean_sim_matrix = 1 / (1 + euclidean_dist_matrix)
# Scale cosine similarities to range [0, 1]
cosine_sim_matrix = 0.5 * (cosine_sim_matrix + 1)  

euclidean_sim_df = pd.DataFrame(euclidean_sim_matrix, index=df['country'], columns=df['country'])
cosine_sim_df = pd.DataFrame(cosine_sim_matrix, index=df['country'], columns=df['country'])

print("Euclidean Similarity Matrix after PCA:")
print(euclidean_sim_df)

print("\nCosine Similarity Matrix after PCA:")
print(cosine_sim_df)
# Out:
# Euclidean Similarity Matrix after PCA:
# country              Afghanistan   Albania   Algeria    Angola  \
# country
# Afghanistan             1.000000  0.226647  0.271378  0.384608
# Albania                 0.226647  1.000000  0.578906  0.197451
# Algeria                 0.271378  0.578906  1.000000  0.226718
# Angola                  0.384608  0.197451  0.226718  1.000000
# Antigua and Barbuda     0.202150  0.514595  0.408912  0.190064
# ...                          ...       ...       ...       ...
# Vanuatu                 0.316261  0.363309  0.450723  0.297522
# Venezuela               0.269509  0.459896  0.548598  0.209412
# Vietnam                 0.215095  0.335560  0.332733  0.224999
# Yemen                   0.488788  0.297063  0.378917  0.324079
# Zambia                  0.717651  0.223980  0.267007  0.452184
#
# country              Antigua and Barbuda  Argentina   Armenia  Australia  \
# country
# Afghanistan                     0.202150   0.223062  0.257151   0.150300
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import euclidean_distances, cosine_similarity


similarity_cols = ['child_mort', 'exports', 'health', 'imports', 'income', 'inflation', 'life_expec', 'total_fer', 'gdpp']
X = df[similarity_cols]

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Euclidean distances
euclidean_dist_matrix = euclidean_distances(X_scaled)

# Cosine similarities
cosine_sim_matrix = cosine_similarity(X_scaled)

# Convert distance matrices to similarity matrices
euclidean_sim_matrix = 1 / (1 + euclidean_dist_matrix)
# Scale cosine similarities to range [0, 1]
cosine_sim_matrix = 0.5 * (cosine_sim_matrix + 1)  

euclidean_sim_df = pd.DataFrame(euclidean_sim_matrix, index=df['country'], columns=df['country'])
cosine_sim_df = pd.DataFrame(cosine_sim_matrix, index=df['country'], columns=df['country'])

print("Euclidean Similarity Matrix:")
print(euclidean_sim_df)

print("\nCosine Similarity Matrix:")
print(cosine_sim_df)
# Out:
# Euclidean Similarity Matrix:
# country              Afghanistan   Albania   Algeria    Angola  \
# country
# Afghanistan             1.000000  0.194426  0.204184  0.250022
# Albania                 0.194426  1.000000  0.351896  0.166273
# Algeria                 0.204184  0.351896  1.000000  0.205033
# Angola                  0.250022  0.166273  0.205033  1.000000
# Antigua and Barbuda     0.184725  0.470612  0.320894  0.167216
# ...                          ...       ...       ...       ...
# Vanuatu                 0.257490  0.314857  0.300497  0.217058
# Venezuela               0.157349  0.190168  0.250382  0.169096
# Vietnam                 0.181189  0.306090  0.268007  0.178408
# Yemen                   0.285916  0.240648  0.335713  0.283607
# Zambia                  0.401424  0.190407  0.216858  0.311433
#
# country              Antigua and Barbuda  Argentina   Armenia  Australia  \
# country
# Afghanistan                     0.184725   0.192974  0.199781   0.146923
# ...

# %% [markdown]
# ### Kmeans

# %% [markdown]
# <div dir="rtl">
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3> بعد از پیاده سازی ماتریش شباهت باید در این مرحله الگوریتم Kmeans را پیاده سازی کنید.دقت کنید استفاده از
#     .
# کتابخانه های  آماده مجاز نیست. همچنین مراکز اولیه باید به صورت تصادفی انتخاب شود و تعداد خوشه ها را نیز به صورت بهینه انتتخاب کنید
# الگوریتم را تا  زمانی ادامه دهید که به دقت مناسبی برسد.
# دقت کنید مجدد خوشه بندی را برای هر دو داده کاهش داده شده و اصلی باید انجام دهید.
# </font>
# </p>
# </div>

# %%
import numpy as np

# Return array of random centroids
def getRandomCentroids(num_features, k):
    centroids = np.random.rand(k, num_features)
    return centroids
    
#  Check convergence of the k-means algorithm based on changes in centroids.
def convergence(old_centroids, centroids, iterations, max_iterations=100, threshold=1e-4):
    if iterations >= max_iterations:
        return True
    if old_centroids is not None:
        return np.linalg.norm(centroids - old_centroids) < threshold
    return False

# Assign labels to data points based on centroids
def assignLabels(data, centroids):
    labels = []
    # Iterate over each data point 
    for index, point in data.iterrows():
        # Calculate distances between the current data point and all centroids
        distances = [np.linalg.norm(point - centroid) for centroid in centroids]
        # Assign the label of the closest centroid to the current data point
        label = np.argmin(distances)
        labels.append(label)
    return np.array(labels)

# Update centroids based on assigned labels
def getCentroids(labels, dataset, k):
    centroids = []
    for i in range(k):
        cluster_points = dataset[labels == i]
        if len(cluster_points) > 0:
            centroids.append(cluster_points.mean(axis=0))
        else:
            centroids.append(np.zeros(cluster_points.shape[1]))
    return np.array(centroids)
    
# Perform k-means clustering
def kmeans(dataset, k):
    num_features = dataset.shape[1]
    centroids = getRandomCentroids(num_features, k)

    iterations = 0
    old_centroids = None
    # Iterate until convergence
    while not convergence(old_centroids, centroids, iterations):
        old_centroids = centroids
        iterations += 1
        labels = assignLabels(dataset, centroids)
        centroids = getCentroids(labels, dataset, k)
    return centroids
    
# Perform elbow method to find optimal k
def elbow_method(data, max_k):
    wcss = []
    for k in range(1, max_k + 1):
        centroids = kmeans(data, k)
        labels = assignLabels(data, centroids)        
        wcss.append(np.sum((data.values - centroids[labels])**2))
    plt.plot(range(1, max_k + 1), wcss)
    plt.xlabel('Number of Clusters (k)')
    plt.ylabel('Within-Cluster Sum of Squares (WCSS)')
    plt.title('Elbow Method for Optimal k')
    plt.show()

# %% [markdown]
# # Results

# %% [markdown]
# <div dir="rtl">
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در این مرحله نیاز است که نموداری بر اساس خوشه های خود همچنین دقت الگوریتم خود را به صورت نمودار و عددی نشان دهید.
#
# </font>
# </p>
# </div>

# %% [markdown]
# ### K-means for data redecued by PCA

# %%
# Performing elbow metgod to find optimal k from plot
elbow_method(pca_df,10)

# %%
k = 4  # Number of clusters finding it out from elbow method
centroids = kmeans(pca_df, 4)

# Assign labels to data points based on the centroids
PCA_data_output_labels = assignLabels(pca_df, centroids)

# Create a scatter plot
plt.figure(figsize=(8, 6))
for label in range(k):
    indices = [i for i, x in enumerate(PCA_data_output_labels) if x == label]
    plt.scatter(pca_df.iloc[indices, 0], pca_df.iloc[indices, 1], label=f'Label {label}')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='X', s=200, c='red', label='Centroids')

plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA')
plt.legend()
plt.show()

# %% [markdown]
# ### K-means for actual dataset

# %%
# Normalize features
# pca_cols are features which are numerical
df_normalized = df.copy() 
df_normalized[pca_cols] = scaler.fit_transform(df_normalized[pca_cols])
data = df_normalized[pca_cols]

# %%
# Performing elbow metgod to find optimal k from plot
elbow_method(data,10)
# Out:
# [[-3.72290356e-17  2.12737346e-16  5.50457883e-16  2.76558550e-16
#   -7.97765048e-17 -1.06368673e-17  3.69631139e-16  3.04480327e-16
#    5.85027702e-17]]
# 1503.0
# [[-0.65594576  0.29127521  0.22908193  0.11784904  0.48985836 -0.28650762
#    0.69642291 -0.68226854  0.44335404]
#  [ 0.86548399 -0.38432146 -0.30226087 -0.15549526 -0.64634089  0.37803089
#   -0.91889134  0.90021544 -0.58498102]]
# 1051.160639381118
# [[ 1.41356446 -0.45761494 -0.18789794 -0.18989721 -0.70783863  0.39898875
#   -1.29703104  1.40287396 -0.61276131]
#  [-0.39328196 -0.03058375 -0.20617903  0.01956247 -0.25093021 -0.00578315
#    0.22676244 -0.40257862 -0.35583225]
#  [-0.82744866  0.64507985  0.72741122  0.19063895  1.48424268 -0.48492064
#    1.07957853 -0.79187687  1.61599536]]
# 831.5351582151586
# [[-0.43706491  0.02737909 -0.19090588  0.06955093 -0.20131886 -0.03918493
#    0.28566125 -0.44720856 -0.31752579]
#  [ 1.34541883 -0.45967186 -0.1895969  -0.22567743 -0.68713515  0.39226703
# ...

# %%
k = 4  # Number of clusters

centroids = kmeans(data, k)
original_data_output_labels = assignLabels(data, centroids)

data['Label'] = original_data_output_labels
# Scatter matrix with labels
sns.pairplot(data, vars=pca_cols, hue='Label', palette='viridis')
plt.title('Scatter Matrix with Labels')
plt.show()

# %% [markdown]
# ## Silluete Score

# %%
from sklearn.metrics import silhouette_score, silhouette_samples
silhouette_avg_PCA_data = silhouette_score(pca_df, PCA_data_output_labels)
silhouette_avg_original_data = silhouette_score(data, original_data_output_labels)
print("silhouette avg PCA data : ", silhouette_avg_PCA_data)
print("silhouette avg original data : ", silhouette_avg_original_data)
# Out:
# silhouette avg PCA data :  0.3924682
# silhouette avg original data :  0.3487582135629547

# %% [markdown]
# <div dir="rtl">
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3> نتایج به دست آمده بالا را با یکدیگر مقایسه کرده و نتیجه را توجیه کنید.
# </font>
# </p>
# </div>

# %% [markdown]
# ### DBSCAN

# %% [markdown]
# <div dir="rtl">
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# الگوریتم DBSCAN را بر هر دو داده کاهش داده شده و اصلی پساده سازی کنید.
#     مجددا نمی توانید در اینجا از کتابخانه های آماده استفاده کنید.
# </font>
# </p>
# </div>

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import silhouette_score
import numpy as np
import matplotlib.pyplot as plt

def find_optimal_eps(df, min_samples, max_eps):
    neigh = NearestNeighbors(n_neighbors=min_samples)
    neigh.fit(df)
    distances, _ = neigh.kneighbors(df)
    distances = np.sort(distances[:, -1])
    
    # Elbow method
    plt.plot(distances)
    plt.xlabel('Points')
    plt.ylabel('Distance')
    plt.title('Elbow Method for Optimal Eps')
    plt.show()

    knee_point = np.argmax(np.diff(distances)) + 1
    return distances[knee_point]


def find_optimal_min_samples(df, eps, min_samples_range):
    silhouette_scores = []
    for min_samples in min_samples_range:
        labels = dbscan(df, eps=eps, min_samples=min_samples)
        if len(np.unique(labels)) > 1:  # Exclude single cluster case
            silhouette_scores.append(silhouette_score(df, labels))
        else:
            silhouette_scores.append(-1)  # Assign a low score for single cluster case
    
    optimal_min_samples = min_samples_range[np.argmax(silhouette_scores)]
    return optimal_min_samples

# %%
## TODO
import numpy as np

def dbscan(df, eps, min_samples):
    labels = np.full(len(df), -1)  # Initialize labels as noise (-1)
    cluster_id = 0

    for i, point in df.iterrows():
        if labels[i] != -1:  # Skip points that are already assigned to a cluster
            continue

        neighbors = region_query(df, i, eps)
        if len(neighbors) < min_samples:
            labels[i] = -1  # Mark as noise
        else:
            cluster_id += 1
            expand_cluster(df, labels, i, neighbors, cluster_id, eps, min_samples)

    return labels

def region_query(df, idx, eps):
    neighbors = []
    for i, point in df.iterrows():
        if np.linalg.norm(df.iloc[idx] - point) <= eps and i != idx:
            neighbors.append(i)
    return neighbors

def expand_cluster(df, labels, idx, neighbors, cluster_id, eps, min_samples):
    labels[idx] = cluster_id

    i = 0
    while i < len(neighbors):
        n = neighbors[i]
        if labels[n] == -1:  # Mark as cluster member
            labels[n] = cluster_id
            new_neighbors = region_query(df, n, eps)
            if len(new_neighbors) >= min_samples:
                neighbors.extend(new_neighbors)
        elif labels[n] == 0:  # Mark as border point (not core point)
            labels[n] = cluster_id
        i += 1

# Example usage:

# %% [markdown]
# ### Results

# %% [markdown]
# <div dir="rtl">
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در این مرحله نیاز است که نموداری بر اساس خوشه های خود همچنین دقت الگوریتم خود را به صورت نمودار و عددی نشان دهید.
# همچنین مقادری بهینه minpts و eps را گزارش کنید.
# </font>
# </p>
# </div>

# %%
output_labels = dbscan(pca_df, eps=0.5, min_samples=5)
plt.figure(figsize=(8, 6))

k = len(np.unique(output_labels)) 


indices = [i for i, x in enumerate(output_labels) if x == -1 ]
plt.scatter(pca_df.iloc[indices, 0], pca_df.iloc[indices, 1], label='noise', facecolor='none', color='gray',marker='o')


for label in range(1,k):
    indices = [i for i, x in enumerate(output_labels) if x == label ]
    plt.scatter(pca_df.iloc[indices, 0], pca_df.iloc[indices, 1], label=f'Label {label }')

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Scatter Plot with Labels')
plt.legend()
plt.show()
# Out:
# [ 1  2  2 -1  2  2  2  3  5  2  2  2  2  2  2 -1  2  1  2  2  2  2 -1  4
#   2  1  1  2  1  3  2 -1 -1  2  2  2  1  1 -1  2 -1  2  4  4  5  2  2  2
#   2 -1  1  2  2  5  3  2  1  2  5  1  3  2  2  1  1  2 -1 -1  5  2  2  2
#   2 -1  2  3  2  3  2  2  1  2  4  2  2  2  2 -1 -1  2  2 -1  2  1  1 -1
#   2  1 -1 -1  2  2  2  2  2  2  1 -1  2  2 -1  3 -1 -1 -1  2  1  2  2  2
#   2  2  3 -1  2  2  2  2  2  1  2 -1  1 -1 -1  4  2  2  4  3  2  2  1  2
#   5 -1  2  1  2 -1 -1  2  2  2  2  1  2 -1  3 -1  2  2  2  2 -1  1  1]

# %% [markdown]
# <div dir="rtl">
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# نتایج به دست آمده از مرحله قبل را با این مرحله مقایسه کرده و علت بهتر بودن الگوریتم بهینه را توجیه کنید
# </font>
# </p>
# </div>

# %% [markdown]
# ## Association rules

# %% [markdown]
# <div dir="rtl">
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در این مرحله باید هر دو دیتا ست داده شده به شما را خوانده و سپس برای محموعه داده کوچکتر آستانه پشتیبانی و آستانه اطمینان را به صورت ورودی از کاربر گرفته و سپس تمام قوانین انجمنی معتبر را برای آن ها به دست آورید.
#     برای مجموعه داده های بزرگتر نیز مجدد آستانه پشتنیبانی و اطمینان را دریافت کرده و 3 کالایی که بیشترین خرید را با هم داشته اند به دست آورید.
# </font>
# </p>
# </div>

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# Read the CSV file into a DataFrame
df = pd.read_csv('GroceryStoreDataSet.csv', header=None)

transactions = df[0].str.split(',')

# Convert the list of lists into a list of strings
transactions = transactions.apply(lambda x: [str(i) for i in x])
transactions = transactions.values.tolist()

# One-hot encode the transactions (1-itemsets in each record)
oht = TransactionEncoder()
oht_ary = oht.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(oht_ary, columns=oht.columns_)

min_support = float(input("Enter the minimum support threshold (between 0 and 1): "))
min_confidence = float(input("Enter the minimum confidence threshold (between 0 and 1): "))

# Find frequent itemsets using the Apriori algorithm
frequent_itemsets = apriori(df_encoded, min_support=min_support, use_colnames=True)

# Find association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence).sort_values(by='confidence', ascending=False)

# Print the association rules
for index, rule in rules.iterrows():
    antecedents = ', '.join(rule['antecedents'])
    consequents = ', '.join(rule['consequents'])
    confidence = round(rule['confidence'], 3)
    print(f"confidence = {confidence}     {antecedents} -> {consequents}\t")
# Out:
# Enter the minimum support threshold (between 0 and 1):  0.2
# Enter the minimum confidence threshold (between 0 and 1):  0.4
# confidence = 0.8     MILK -> BREAD
# confidence = 0.8     MAGGI -> TEA
# confidence = 0.667     SUGER -> BREAD
# confidence = 0.667     CORNFLAKES -> COFFEE
# confidence = 0.667     SUGER -> COFFEE
# confidence = 0.571     BISCUIT -> BREAD
# confidence = 0.571     TEA -> BREAD
# confidence = 0.571     TEA -> MAGGI
# confidence = 0.5     COFFEE -> CORNFLAKES
# confidence = 0.5     COFFEE -> SUGER

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# Read the CSV file into a DataFrame
df = pd.read_csv('Grocery Products Purchase.csv')
transactions = df.apply(lambda x: x.dropna().tolist(), axis=1)

# One-hot encode the transactions (1-itemsets in each record)
oht = TransactionEncoder()
oht_ary = oht.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(oht_ary, columns=oht.columns_)

# print(df_encoded)
frequent_itemsets = apriori(df_encoded, min_support=0.01, use_colnames=True)

# Filter the frequent itemsets to include only those with 3 items
frequent_3_itemsets = frequent_itemsets[frequent_itemsets['itemsets'].apply(lambda x: len(x)) == 3]

# Sort the frequent 3-itemsets dataframe by support in descending order
frequent_3_itemsets_sorted = frequent_3_itemsets.sort_values(by='support', ascending=False)

# Select the most frequent 3-itemset (top 1)
most_frequent_3_itemset = frequent_3_itemsets_sorted.iloc[0]

# Print the most frequent 3-itemset
print("Most frequent 3-itemset:")
print(most_frequent_3_itemset)
# Out:
# Most frequent 3-itemset:
# support                                            0.023183
# itemsets    (root vegetables, other vegetables, whole milk)
# Name: 316, dtype: object
